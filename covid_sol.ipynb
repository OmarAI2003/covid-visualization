# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("covid.csv",index_col='Country/Region')

# %%
df['total']=df.iloc[:,3:].sum(axis=1)

# %%
df.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  11/25/20  11/26/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     45384     45600
# Albania               0        0        0        0  ...     34944     35600
# Algeria               0        0        0        0  ...     78025     79110
# Andorra               0        0        0        0  ...      6428      6534
# ...

# %%
top5=df.sort_values('total',ascending=False)[:5].iloc[:,3:-1]

# %%
top5.T.plot()
plt.xlabel('Date')
plt.ylabel('Count of deaths')
# Out:
# Text(0, 0.5, 'Count of deaths')
